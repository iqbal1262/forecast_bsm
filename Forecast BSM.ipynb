# %% [markdown]
# # Import Data

# %%
from pmdarima import auto_arima
print("✅ pmdarima ready to use!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from pmdarima import auto_arima
#       2 print("✅ pmdarima ready to use!")
#
# ModuleNotFoundError: No module named 'pmdarima'

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os

import plotly.graph_objects as go
import plotly.express as px

# %%
pd.set_option('display.max_columns', None)

# %%
bsm_all = pd.read_excel('data/bsm_all.xlsx').drop(columns = ['KETBPB'])
bsm_all.head()
# Out:
#              NO_BSM                                        NAMA_BARANG  \
# 0  BSM/004558/03/23  P553000/ J86-19009 LUBE FILTER,SPIN-ON FULL FL...
# 1  BSM/004558/03/23  FF-232/ P55-7440 FUEL FILTER,SPIN-ON SECONDARY...
# 2  BSM/004558/03/23                               FILTER RACOR FH 1000
# 3  BSM/004555/03/23                                           ORING 30
# 4  BSM/004555/03/23                                   ORING G 80 VITON
#
#    JUMLAH  JMLDISETUJUI  HRGSATUAN       TOTAL STATUS BSM_CREATED_ON  \
# 0     2.0           2.0  334374.47   668748.94  CLOSE     18/03/2023
# 1     6.0           6.0   62328.25   373969.50  CLOSE     18/03/2023
# 2     2.0           2.0  749600.00  1499200.00  CLOSE     18/03/2023
# 3     3.0           3.0   30000.00    90000.00  CLOSE     18/03/2023
# 4     3.0           3.0   16999.81    50999.43  CLOSE     18/03/2023
#
#                  NO_BPB       KODEBARANG KODELOKASI JENISSTOK  \
# 0  BPB/000327/UMU/03/23     FLTRJB619009       KLNK      JADI
# 1  BPB/000327/UMU/03/23   FLTRFF-232/P55       KLNK      JADI
# 2  BPB/000327/UMU/03/23  FLTRRACORFH1000       KLNK      JADI
# 3   BPB/000033/MR/03/23         ORING30.       KLNK      JADI
# 4   BPB/000033/MR/03/23       ORINGG800V       KLNK      JADI
#
#                NOLOKB USERIDAPP             DATEAPP BSM_CLOSED_BY  \
# 0                 NaN    novi_h 2023-03-30 08:37:53         msafi
# 1                 NaN    novi_h 2023-03-30 08:37:53         msafi
# 2                 NaN    novi_h 2023-03-30 08:37:53         msafi
# 3  LOKB/0139/MR/02/23     avian 2023-03-18 10:29:15         avian
# 4  LOKB/0139/MR/02/23     avian 2023-03-18 10:29:15         avian
#
#         BSM_CLOSED_ON LOKASIBUAT KODEKAPAL KODEALATBERAT    NAMAOBJEK  \
# 0 2023-04-05 19:22:25       KLNK       NaN           NaN          NaN
# 1 2023-04-05 19:22:25       KLNK       NaN           NaN          NaN
# 2 2023-04-05 19:22:25       KLNK       NaN           NaN          NaN
# 3 2023-03-18 10:29:15       KLNK       KAA           NaN  KAPPA (KAA)
# 4 2023-03-18 10:29:15       KLNK       KAA           NaN  KAPPA (KAA)
#
#     KODEAKUNBRG KODEAKUNBSM
# 0  6XX.02.02.01         NaN
# 1  6XX.02.02.01         NaN
# 2     3XX.01.02         NaN
# 3  6XX.02.02.01         NaN
# 4  6XX.02.02.01         NaN
